# %%
import pandas as pd

df_rec=pd.read_excel("data/data_w_functions.xlsx",sheet_name="recipes")
df_quant=pd.read_excel("data/data_w_functions.xlsx",sheet_name="quantity")
df_meas=pd.read_excel("data/data_w_functions.xlsx",sheet_name="measurement",na_values="")
df_ingr=pd.read_excel("data/data_w_functions.xlsx",sheet_name="ingredient")

df_sp_quant=pd.read_excel("data/data_w_functions.xlsx",sheet_name="quantity_sp")
df_sp_meas=pd.read_excel("data/data_w_functions.xlsx",sheet_name="measurement_sp",na_values="")
df_sp_ingr=pd.read_excel("data/data_w_functions.xlsx",sheet_name="ingredient_sp")

df_quant=pd.concat([df_quant,df_sp_quant],axis=1)
df_meas=pd.concat([df_meas,df_sp_meas],axis=1)
df_ingr=pd.concat([df_ingr,df_sp_ingr],axis=1)

# %%
def get_recipe(str_recipe):
    return df_rec.at[0,str_recipe]

def get_df_ingr(str_recipe,multiplier=1):
    df_1=df_quant[str_recipe]*multiplier
    df_1=df_1.rename('quantity')
    df_1=pd.to_numeric(df_1)
    df_2=df_meas[str_recipe]
    df_2=df_2.rename('measure')
    df_3=df_ingr[str_recipe]
    df_3=df_3.rename('ingredient_name')

    df_out=pd.concat([df_1,df_2,df_3],axis=1)
    df_out.dropna(axis = 0, how = 'all', inplace = True)
    df_out.drop(df_out[df_out['quantity'] <=0].index, inplace = True)

    return df_out

def get_list(recipe_array,multiplier):

    #multiply individually, then combine
    df_combined=get_df_ingr(recipe_array[0])[0:0]
    for i in range(len(recipe_array)):
        df_combined=pd.concat([df_combined,get_df_ingr(recipe_array[i],multiplier[i])])

    df_combined=df_combined.groupby(['ingredient_name'],as_index=False, sort=False).agg({'quantity': 'sum','measure':'first'})

    #now concatenate columns to get single ingredients list
    df_out = df_combined[['quantity','measure','ingredient_name']]
    df_out.fillna('',inplace=True)
    df_out[df_out['measure']=="None"]=""
    df_out['quantity']=df_out['quantity'].apply(lambda x: f'{x:.0f}' if x%1==0 else str(x))
    df_out['ingredients']=df_out['quantity'] + df_out['measure'] + " " + df_out['ingredient_name']
    df_out=df_out.drop(columns=['quantity','measure','ingredient_name'], axis=1)

    return df_out

def get_spice_pots(recipe_array):
    #multiply individually, then combine
    df_combined=get_df_ingr(recipe_array[0])[0:0]
    df_combined=df_combined.drop(columns=['quantity','measure','ingredient_name'],axis=1)
    for i in range(len(recipe_array)):
        df_i=get_df_ingr(recipe_array[i])
        df_sp_i=df_i.loc[df_i['ingredient_name'].str.contains('spice pot')]
        if len(df_sp_i)>0:
            #check if we have spice pot:
                if df_sp_i['ingredient_name'].iat[0] in df_ingr.columns:
                    ingred_list_i=get_list([df_sp_i['ingredient_name'].iat[0]],[1])
                    ingred_list_i.rename(columns={"ingredients":(str(1) + " " + df_sp_i['ingredient_name'].iat[0]) }, inplace=True)
                    df_combined=pd.concat([df_combined,ingred_list_i],axis=1)
                else:
                    df_combined[(str(1) + " " + df_sp_i['ingredient_name'].iat[0])]=""
                    df_combined[(str(1) + " " + df_sp_i['ingredient_name'].iat[0])].iat[0]="We do not have this, please check original card"

    df_combined.fillna('',inplace=True)
    return df_combined

def get_sainsburys_link(recipe_array,multiplier):
    #multiply individually, then combine
    df_combined=get_df_ingr(recipe_array[0])[0:0]
    for i in range(len(recipe_array)):
        df_combined=pd.concat([df_combined,get_df_ingr(recipe_array[i],multiplier[i])])

    df_combined=df_combined.groupby(['ingredient_name'],as_index=False, sort=False).agg({'quantity': 'sum','measure':'first'})

    #now concatenate columns to get single ingredients list
    df_out = df_combined[['quantity','measure','ingredient_name']]
    df_out.fillna('',inplace=True)
    df_out=df_out.drop(columns=['quantity','measure'], axis=1)
    ls_out=df_out['ingredient_name'].tolist()
    str_out=",".join(ls_out)
    sains_link="https://www.sainsburys.co.uk/gol-ui/SearchResults/"
    return sains_link + str_out

# %%
df_quant.head()
# Out:
#    Greek Mushroom Ragu & Olive Oil Mash  Mushroom Risotto Stuffed Squash  \
# 0                                   1.0                              1.0
# 1                                   2.0                             10.0
# 2                                 200.0                              5.0
# 3                                  60.0                              1.0
# 4                                 500.0                              1.0
#
#    Nasi Goreng with Peanuts & Sriracha  Teriyaki Mushroom Rice & Asian Slaw  \
# 0                                 0.33                                150.0
# 1                                 1.00                                  1.0
# 2                                 1.00                                  1.0
# 3                               150.00                                  1.0
# 4                                 1.00                                  1.0
#
#    Greek Pasticcio & Roasted Vegetables  Mushroom & kabocha Squash Pie  \
# 0                                   2.0                            1.0
# 1                                  10.0                            1.0
# 2                                 150.0                          400.0
# 3                                   1.0                           15.0
# 4                                  50.0                           10.0
#
#    Sesame Rice with Teriyaki Mushrooms  Mushroom & Garden Pea Tikka Masala  \
# 0                                200.0                                 1.0
# 1                                150.0                               200.0
# 2                                150.0                               300.0
# 3                                200.0                                 2.0
# 4                                  1.0                                 0.5
#
#    Mushroom Paella with Smoky Chickpeas  Thai Shiitake Stir - fry  ...  \
# 0                                   1.0                     100.0  ...
# 1                                   2.0                     200.0  ...
# 2                                   1.0                       1.0  ...
# 3                                   1.0                     150.0  ...
# 4                                 200.0                       2.0  ...
#
#    dukkah spice pot  cauli taco spice pot  refried bean spice pot  \
# 0               1.0                   1.0                     1.0
# 1               0.5                   1.0                     1.0
# 2               0.5                   1.0                     1.0
# 3               0.5                   NaN                     NaN
# 4               NaN                   NaN                     NaN
#
#    quesadilla spice pot  fajita spice pot  chickpea spice pot  \
# 0                   0.5              1.00                 1.0
# 1                   0.5              1.00                 1.0
# 2                   1.0              0.50                 1.0
# 3                   0.5              0.25                 NaN
# 4                   NaN               NaN                 NaN
#
#    mushroom spice pot  thai spice pot  buffalomi stew spice pot  \
# 0                 1.0             0.5                      1.00
# 1                 1.0             0.5                      0.50
# 2                 NaN             1.0                      0.25
# 3                 NaN             0.5                      0.25
# 4                 NaN             NaN                       NaN
#
#    pepper spice pot
# 0               0.5
# 1               0.5
# 2               0.5
# 3               NaN
# 4               NaN
#
# [5 rows x 253 columns]

# %%
df_ingr
# Out:
#    Greek Mushroom Ragu & Olive Oil Mash Mushroom Risotto Stuffed Squash  \
# 0                             red onion                            leek
# 1                                garlic                        rosemary
# 2                  portobello mushrooms                 dried mushrooms
# 3                          green olives                spaghetti squash
# 4                              potatoes                 bouillon powder
# 5                    dark green lentils                      brown miso
# 6                       greek spice pot                          garlic
# 7                              red wine                       mushrooms
# 8                               passata                    risotto rice
# 9                               parsley                      white wine
# 10                              spinach                       radicchio
# 11                               lemons                           thyme
# 12                                  NaN         toasted whole hazelnuts
# 13                                  NaN                   chilli flakes
# 14                                  NaN                balsamic vinegar
# 15                                  NaN                             NaN
# 16                                  NaN                             NaN
# 17                                  NaN                             NaN
# 18                                  NaN                             NaN
#
#    Nasi Goreng with Peanuts & Sriracha Teriyaki Mushroom Rice & Asian Slaw  \
# 0                             cucumber                  brown basmati rice
# 1                         rice vinegar                           red onion
# 2                    light brown sugar                             carrots
# 3                   brown basmati rice                         red cabbage
# 4                      pointed cabbage                  sweet chilli sauce
# 5                        spring onions                       chilli flakes
# 6                              carrots                               limes
# 7                            coriander                           mushrooms
# 8                              peanuts                           coriander
# 9                        ground ginger                         cashew nuts
# 10                       chilli flakes                      teriyaki sauce
# 11                               limes                               mirin
# 12                                eggs                              tamari
# 13                            sriracha                  toasted sesame oil
# 14                                 NaN                                 NaN
# 15                                 NaN                                 NaN
# 16                                 NaN                                 NaN
# 17                                 NaN                                 NaN
# 18                                 NaN                                 NaN
#
#    Greek Pasticcio & Roasted Vegetables Mushroom & kabocha Squash Pie  \
# 0                             red onion                kabocha squash
# 1                              rosemary                          leek
# 2                             mushrooms                     mushrooms
# 3                                garlic                         thyme
# 4                               walnuts                   plain flour
# 5             chopped toasted hazelnuts               Worcester sauce
# 6                           plain flour                    brown miso
# 7                       Worcester sauce                  tomato puree
# 8                               passata                      red wine
# 9                             soy cream                 pumpkin seeds
# 10                      ground cinnamon                    curly kale
# 11                          penne pasta                        garlic
# 12                           red pepper                        lemons
# 13                        yellow pepper                           NaN
# 14                           courgettes                           NaN
# 15                      cherry tomatoes                           NaN
# 16                               olives                           NaN
# 17                                 mint                           NaN
# 18                               lemons                           NaN
#
#    Sesame Rice with Teriyaki Mushrooms Mushroom & Garden Pea Tikka Masala  \
# 0                   chestnut mushrooms                              onion
# 1                   shiitake mushrooms                          mushrooms
# 2                   white basmati rice                       new potatoes
# 3                  tenderstem broccoli                             garlic
# 4                            red onion                      ground ginger
# 5                               garlic                  tikka spice paste
# 6                               ginger                          chickpeas
# 7                   toasted sesame oil                            passata
# 8                              peanuts                       coconut milk
# 9                       teriyaki sauce                        garden peas
# 10                        sesame seeds                      summer greens
# 11                                 NaN                          coriander
# 12                                 NaN                      chilli flakes
# 13                                 NaN                             lemons
# 14                                 NaN              toasted coconut chips
# 15                                 NaN                                NaN
# 16                                 NaN                                NaN
# 17                                 NaN                                NaN
# 18                                 NaN                                NaN
#
#    Mushroom Paella with Smoky Chickpeas Thai Shiitake Stir - fry  ...  \
# 0                                 onion       brown basmati rice  ...
# 1                                garlic             coconut milk  ...
# 2                            red pepper                    onion  ...
# 3                         yellow pepper       shiitake mushrooms  ...
